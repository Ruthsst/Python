# %% [markdown]
# Incluir =pandas= para generar números aleatoreos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 10000
a = 0
b = 1
data = np.random.uniform(a,b,n)
print (data)
# Out:
# [0.37043429 0.26995644 0.55767459 ... 0.68411486 0.29168945 0.20951852]

# %% [markdown]
# Tipo de dato

# %%
type(data)
# Out:
# numpy.ndarray

# %% [markdown]
# Tamaño del arreglo

# %%
len(data)
# Out:
# 10

# %%
t = range(len(data))

# %%
t
# Out:
# range(0, 10)

# %% [markdown]
# Para asentar los gráficos se usa

# %%
# %matplotlib inline

# %%
 plt.hist(data)
# Out:
# (array([ 941.,  993., 1077., 1035.,  993., 1003., 1018.,  999.,  982.,
#          959.]),
#  array([1.34916331e-04, 1.00119726e-01, 2.00104536e-01, 3.00089346e-01,
#         4.00074156e-01, 5.00058966e-01, 6.00043776e-01, 7.00028586e-01,
#         8.00013396e-01, 8.99998206e-01, 9.99983016e-01]),
#  <a list of 10 Patch objects>)

# %%
data = np.random.randn(n)
x = range (1, n+1)
x = np.array(x)
type(x)
# Out:
# numpy.ndarray

# %%
plt.plot(x,data)

# %%
plt.hist(data)
# Out:
# (array([   4.,   87.,  431., 1217., 2202., 2742., 2081.,  896.,  291.,
#           49.]),
#  array([-3.74522452, -3.04801472, -2.35080493, -1.65359513, -0.95638533,
#         -0.25917554,  0.43803426,  1.13524406,  1.83245385,  2.52966365,
#          3.22687345]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(x,sorted(data))

# %%
n=1000
errores = np.random.randn(1000)
sigma = 5
errores *= sigma

# %%
plt.hist(errores)
# Out:
# (array([  3.,  30., 100., 214., 265., 216., 114.,  47.,   4.,   7.]),
#  array([-15.13196816, -11.86510983,  -8.5982515 ,  -5.33139318,
#          -2.06453485,   1.20232348,   4.4691818 ,   7.73604013,
#          11.00289846,  14.26975679,  17.53661511]),
#  <a list of 10 Patch objects>)

# %%
np.var(errores)
# Out:
# 23.535566258194507

# %%
x=range(1,n)

# %%
a = 0
b = 1
ygorro = a*x + b

# %%
url_datos = "http://winterolympicsmedals.com/medals.csv"

# %%
models_data = pd.read_csv(url_datos)

# %%
models_data.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
models_data.shape
# Out:
# (2311, 8)

# %%
models_data.columns.values
# Out:
# array(['Year', 'City', 'Sport', 'Discipline', 'NOC', 'Event',
#        'Event gender', 'Medal'], dtype=object)

# %%
type(x)
# Out:
# range

# %%
x
# Out:
# array([    1,     2,     3, ...,  9998,  9999, 10000])
