# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
n=10000
a=0
b=1
data= np.random.uniform(a,b,n)

# %%
#data

# %%
type(data)
# Out:
# numpy.ndarray

# %%
len(data)
# Out:
# 10000

# %%
t=range(len(data))

# %%
# %matplotlib inline

# %%
plt.hist(data)
# Out:
# (array([ 976., 1018.,  956., 1001.,  993., 1015., 1041.,  987.,  976.,
#         1037.]),
#  array([1.01860358e-05, 9.99980609e-02, 1.99985936e-01, 2.99973811e-01,
#         3.99961685e-01, 4.99949560e-01, 5.99937435e-01, 6.99925310e-01,
#         7.99913185e-01, 8.99901059e-01, 9.99888934e-01]),
#  <a list of 10 Patch objects>)

# %%
data=np.random.randn(n)
x=range(1,n+1)

# %%
plt.plot(x,data)

# %%
plt.hist(data)
# Out:
# (array([  37.,  220.,  901., 2028., 2826., 2351., 1214.,  352.,   61.,
#           10.]),
#  array([-3.41681021, -2.68461377, -1.95241733, -1.22022089, -0.48802445,
#          0.24417198,  0.97636842,  1.70856486,  2.4407613 ,  3.17295774,
#          3.90515418]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(x,sorted(data))

# %%
errores=np.random.randn(n)

# %%
sigma=5

# %%
errores*=sigma

# %%
plt.hist(errores)
# Out:
# (array([  22.,  174.,  697., 1682., 2633., 2570., 1505.,  588.,  106.,
#           23.]), array([-17.33873144, -13.82431341, -10.30989538,  -6.79547735,
#          -3.28105932,   0.23335871,   3.74777673,   7.26219476,
#          10.77661279,  14.29103082,  17.80544885]), <a list of 10 Patch objects>)

# %%
np.var(errores)
# Out:
# 24.681462261386795

# %%
x=range(n)

# %%
a=0
b=1

# %%
len(x)
len(x)
# Out:
# 10000

# %%
# importar datos
url_datos = "http://winterolympicsmedals.com/medals.csv"

# %%
models_data = pd.read_csv(url_datos)

# %%
models_data.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
models_data.shape
# Out:
# (2311, 8)
